# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])
series
# series = 1-dimensional
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# dataframe = 2-dimensional
car_data = pd.DataFrame({"car_make": series, "Colour": colours})
car_data
# Out:
#   car_make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500
# 7   Honda   Blue     54738      4   $7,000
# 8  Toyota  White      6000      4   $6,250
# 9  Nissan  White     31600      4   $9,700

# %%
# Exporting a dataframe
car_sales.to_csv("Exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("Exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500
# 7   Honda   Blue     54738      4   $7,000
# 8  Toyota  White      6000      4   $6,250
# 9  Nissan  White     31600      4   $9,700

# %% [markdown]
# ## Describe Data

# %%
# Attributes
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Doors        int64
# Price       object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() # describe() work for integers
# Out:
#             Odometer      Doors
# count      10.000000  10.000000
# mean    73201.400000   4.000000
# std     66005.814655   0.471405
# min      6000.000000   3.000000
# 25%     31837.250000   4.000000
# 50%     50218.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      10 non-null     object
#  1   Colour    10 non-null     object
#  2   Odometer  10 non-null     int64
#  3   Doors     10 non-null     int64
#  4   Price     10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5764/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer    73201.4
# Doors           4.0
# dtype: float64

# %%
car_prices =  pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make        ToyotaToyotaHondaBMWNissanToyotaHondaHondaToyo...
# Colour          WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer                                               732014
# Doors                                                      40
# Price       $4,000 $5,000 $7,000 $22,000 $3,500 $4,500 $7,...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales) #length of car_sales
# Out:
# 10

# %% [markdown]
#  ## Viewing and Selecting Data

# %%
car_sales.head() # Print out the first 5
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500

# %%
car_sales.head(7) # This print out the first 7
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500

# %%
car_sales.tail() # Print out the last 5
# Out:
#      Make Colour  Odometer  Doors    Price
# 5  Toyota  Green     99213      4  $4,500
# 6   Honda   Blue     45698      4  $7,500
# 7   Honda   Blue     54738      4  $7,000
# 8  Toyota  White      6000      4  $6,250
# 9  Nissan  White     31600      4  $9,700

# %%
car_sales.tail(3) # Print out the last three
# Out:
#      Make Colour  Odometer  Doors    Price
# 7   Honda   Blue     54738      4  $7,000
# 8  Toyota  White      6000      4  $6,250
# 9  Nissan  White     31600      4  $9,700

# %%
# .loc  &  .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0, 3, 9, 8, 3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# .loc means location / index
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500
# 7   Honda   Blue     54738      4   $7,000
# 8  Toyota  White      6000      4   $6,250
# 9  Nissan  White     31600      4   $9,700

# %%
car_sales.loc[3]
# Out:
# Make             BMW
# Colour         Black
# Odometer       11179
# Doors              5
# Price       $22,000
# Name: 3, dtype: object

# %%
# .iloc means position
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000

# %%
# car_sales["Make"]
car_sales.Make

# Both performs the same operation, but .Make doesn't work for spaces
# Out:
# 0    Toyota
# 1    Toyota
# 2     Honda
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    150043      4  $4,000
# 1  Toyota    Red     87899      4  $5,000
# 5  Toyota  Green     99213      4  $4,500
# 8  Toyota  White      6000      4  $6,250

# %%
car_sales[car_sales["Odometer"] > 100000]
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    150043      4  $4,000
# 4  Nissan  White    213095      4  $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500
# 7   Honda   Blue     54738      4   $7,000
# 8  Toyota  White      6000      4   $6,250
# 9  Nissan  White     31600      4   $9,700

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# .crosstab() compare columns
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   1  2  0
# Nissan  0  2  0
# Toyota  0  4  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#              Odometer     Doors
# Make
# BMW      11179.000000  5.000000
# Honda    44328.333333  3.666667
# Nissan  122347.500000  4.000000
# Toyota   85788.750000  4.000000

# %%
# If the visualization doesn't work, try this:

# %matplotlib inline
# import matplotlib.pyplot as plt
# the % means to plot inside the table

# %%
car_sales["Odometer"].plot();

# %%
car_sales["Odometer"].hist();

# %%
car_sales["Price"].dtype

# the "o" means "object"
# Out:
# dtype('O')

# %%
# car_sales["Price"].plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   $4,000
# 1  Toyota    Red     87899      4   $5,000
# 2   Honda   Blue     32549      3   $7,000
# 3     BMW  Black     11179      5  $22,000
# 4  Nissan  White    213095      4   $3,500
# 5  Toyota  Green     99213      4   $4,500
# 6   Honda   Blue     45698      4   $7,500
# 7   Honda   Blue     54738      4   $7,000
# 8  Toyota  White      6000      4   $6,250
# 9  Nissan  White     31600      4   $9,700

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5764/3261752366.py in <module>
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "").astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White    150043      4   4000
# 1  Toyota    Red     87899      4   5000
# 2   Honda   Blue     32549      3   7000
# 3     BMW  Black     11179      5  22000
# 4  Nissan  White    213095      4   3500
# 5  Toyota  Green     99213      4   4500
# 6   Honda   Blue     45698      4   7500
# 7   Honda   Blue     54738      4   7000
# 8  Toyota  White      6000      4   6250
# 9  Nissan  White     31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1    toyota
# 2     honda
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales

# The lower() won't reflect since it has not been saved
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White    150043      4   4000
# 1  Toyota    Red     87899      4   5000
# 2   Honda   Blue     32549      3   7000
# 3     BMW  Black     11179      5  22000
# 4  Nissan  White    213095      4   3500
# 5  Toyota  Green     99213      4   4500
# 6   Honda   Blue     45698      4   7500
# 7   Honda   Blue     54738      4   7000
# 8  Toyota  White      6000      4   6250
# 9  Nissan  White     31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  toyota  White    150043      4   4000
# 1  toyota    Red     87899      4   5000
# 2   honda   Blue     32549      3   7000
# 3     bmw  Black     11179      5  22000
# 4  nissan  White    213095      4   3500
# 5  toyota  Green     99213      4   4500
# 6   honda   Blue     45698      4   7500
# 7   honda   Blue     54738      4   7000
# 8  toyota  White      6000      4   6250
# 9  nissan  White     31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                    inplace=True)

car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  toyota  White    150043      4   4000
# 1  toyota    Red     87899      4   5000
# 2   honda   Blue     32549      3   7000
# 3     bmw  Black     11179      5  22000
# 4  nissan  White    213095      4   3500
# 5  toyota  Green     99213      4   4500
# 6   honda   Blue     45698      4   7500
# 7   honda   Blue     54738      4   7000
# 8  toyota  White      6000      4   6250
# 9  nissan  White     31600      4   9700

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats
# 0  toyota  White    150043      4   4000    5.0
# 1  toyota    Red     87899      4   5000    5.0
# 2   honda   Blue     32549      3   7000    5.0
# 3     bmw  Black     11179      5  22000    5.0
# 4  nissan  White    213095      4   3500    5.0
# 5  toyota  Green     99213      4   4500    NaN
# 6   honda   Blue     45698      4   7500    NaN
# 7   honda   Blue     54738      4   7000    NaN
# 8  toyota  White      6000      4   6250    NaN
# 9  nissan  White     31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats
# 0  toyota  White    150043      4   4000    5.0
# 1  toyota    Red     87899      4   5000    5.0
# 2   honda   Blue     32549      3   7000    5.0
# 3     bmw  Black     11179      5  22000    5.0
# 4  nissan  White    213095      4   3500    5.0
# 5  toyota  Green     99213      4   4500    5.0
# 6   honda   Blue     45698      4   7500    5.0
# 7   honda   Blue     54738      4   7000    5.0
# 8  toyota  White      6000      4   6250    5.0
# 9  nissan  White     31600      4   9700    5.0

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]

car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM
# 0  toyota  White    150043      4   4000    5.0             7.5
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 8  toyota  White      6000      4   6250    5.0             3.0
# 9  nissan  White     31600      4   9700    5.0             4.5

# %%
car_sales["Total fuel used(L)"] = car_sales["Odometer"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White    150043      4   4000    5.0             7.5
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 8  toyota  White      6000      4   6250    5.0             3.0
# 9  nissan  White     31600      4   9700    5.0             4.5
#
#    Total fuel used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1073.184
# 4           18539.265
# 5            4663.011
# 6            3473.048
# 7            4762.206
# 8             180.000
# 9            1422.000

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White    150043      4   4000    5.0             7.5
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 8  toyota  White      6000      4   6250    5.0             3.0
# 9  nissan  White     31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of wheels
# 0           11253.225                 4
# 1            8086.708                 4
# 2            1627.450                 4
# 3            1073.184                 4
# 4           18539.265                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer                int64
# Doors                   int64
# Price                   int32
# Seats                 float64
# Fuel per 100KM        float64
# Total fuel used(L)    float64
# Number of wheels        int64
# Passed road safety       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White    150043      4   4000    5.0             7.5
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 8  toyota  White      6000      4   6250    5.0             3.0
# 9  nissan  White     31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# 2            1627.450                 4                True
# ...

# %%
# # To remove a column
# car_sales = car_sales.drop("Total fuel used(L)", axis=1)
# car_sales

# %%
# Shuffle
# frac=1 select 100% of the data

car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 8  toyota  White      6000      4   6250    5.0             3.0
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 0  toyota  White    150043      4   4000    5.0             7.5
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 9  nissan  White     31600      4   9700    5.0             4.5
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 8             180.000                 4                True
# 2            1627.450                 4                True
# 7            4762.206                 4                True
# ...

# %%
# Only select 20% of the data

car_sales_shuffled.sample(frac=0.2)
# Out:
#     Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 7  honda   Blue     54738      4   7000    5.0             8.7
# 6  honda   Blue     45698      4   7500    5.0             7.6
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 7            4762.206                 4                True
# 6            3473.048                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White      6000      4   6250    5.0             3.0
# 1   honda   Blue     32549      3   7000    5.0             5.0
# 2   honda   Blue     54738      4   7000    5.0             8.7
# 3  toyota    Red     87899      4   5000    5.0             9.2
# 4  toyota  White    150043      4   4000    5.0             7.5
# 5   honda   Blue     45698      4   7500    5.0             7.6
# 6  nissan  White     31600      4   9700    5.0             4.5
# 7     bmw  Black     11179      5  22000    5.0             9.6
# 8  nissan  White    213095      4   3500    5.0             8.7
# 9  toyota  Green     99213      4   4500    5.0             4.7
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 0             180.000                 4                True
# 1            1627.450                 4                True
# 2            4762.206                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White    150043      4   4000    5.0             7.5
# 1  toyota    Red     87899      4   5000    5.0             9.2
# 2   honda   Blue     32549      3   7000    5.0             5.0
# 3     bmw  Black     11179      5  22000    5.0             9.6
# 4  nissan  White    213095      4   3500    5.0             8.7
# 5  toyota  Green     99213      4   4500    5.0             4.7
# 6   honda   Blue     45698      4   7500    5.0             7.6
# 7   honda   Blue     54738      4   7000    5.0             8.7
# 8  toyota  White      6000      4   6250    5.0             3.0
# 9  nissan  White     31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# 2            1627.450                 4                True
# ...

# %%
# Applying a function to column
# Conversion from KM to miles

car_sales["Odometer"] = car_sales["Odometer"].apply(lambda x: x / 1.609)
car_sales
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White   93252.330640      4   4000    5.0             7.5
# 1  toyota    Red   54629.583592      4   5000    5.0             9.2
# 2   honda   Blue   20229.334991      3   7000    5.0             5.0
# 3     bmw  Black    6947.793661      5  22000    5.0             9.6
# 4  nissan  White  132439.403356      4   3500    5.0             8.7
# 5  toyota  Green   61661.280298      4   4500    5.0             4.7
# 6   honda   Blue   28401.491610      4   7500    5.0             7.6
# 7   honda   Blue   34019.888129      4   7000    5.0             8.7
# 8  toyota  White    3729.024239      4   6250    5.0             3.0
# 9  nissan  White   19639.527657      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...
